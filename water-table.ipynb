# %% [markdown]
# <img src="http://sonetodigital.com.br/adm/wp-content/uploads/2018/12/logo-fiap.png" width="150" align="left"/>
#
# <br/><br/>
#
# <font size=5 color="#ed145b"><b> Sistemas para internet </b></font><font size=5 color="#ed145b"> - Inteligência Artificial e Machine Learning  | NAC 01 </font>
#
# <font size=4 color="#ed145b"> Profa. Thais Rodrigues Neubauer</font>
# <br/><br/>
# <font size=4 color="#ed145b"> Grupo Cative: </font> <br/>
# <font size=3 color="#000"> Abraão RM: 83983</font><br/>
# <font size=3 color="#000"> Iago RM: </font><br/>
# <font size=3 color="#000"> Nicolas RM: </font><br/>
# <font size=3 color="#000"> Luis RM: </font><br/>
# <font size=3 color="#000"> Rodrigo RM: </font><br/>
# <font size=3 color="#000"> Geovanne RM: </font>

# %% [markdown]
# ## Título da avaliação
#
# Descrição falando sobre avaliação

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("pumpit.csv", index_col=0)

# %% [markdown]
# <br/><br/><br/>
# ### Quais minas estão sem água?

# %%
### Primeira resolução

# %% [markdown]
# <br/><br/><br/>
# ### Quais são as minas com menor quantidade de água?

# %%
### Segunda resolução

# %% [markdown]
# <br/><br/><br/>
# ### Quais minas estão com água o suficiente mas têm qualidade desconhecida?

# %%
### Terceira resolução
enoughWaterMask = data.quantity == "enough";
enoughWater = data[enoughWaterMask]
unknownQuality = enoughWater.water_quality == "unknown";
enoughWater[unknownQuality]
# Out:
#        amount_tsh date_recorded                         funder  gps_height  \
# id
# 29083         0.0    2011-08-04                        Mzee Sh           0
# 63695         0.0    2013-01-16                           Dfid        1481
# 18842         0.0    2011-07-22                             Co        1886
# 17360       500.0    2013-02-10                          Oxfam        1287
# 20279      1000.0    2011-07-23                             De        1916
# ...           ...           ...                            ...         ...
# 22219         0.0    2013-02-15                     World Bank         148
# 66888         0.0    2013-02-02                           Tcrs        1238
# 31761      7500.0    2013-02-15  Professor Ben Ohio University         680
# 56224       100.0    2012-10-17                            Hsw        1209
# 9406          0.0    2011-07-18                             No        1667
#
#               installer  longitude  latitude             wpt_name  \
# id
# 29083             ALLYS  33.079504 -3.009659             Kwa Shij
# 63695         WATER AID  34.644989 -4.742124  Kwa Ismail Mnyankwe
# 18842               DWE  31.352875 -7.687096      Shule Ya Msingi
# 17360             OXFAM  30.074538 -4.248860           Kwa Elnazi
# 20279               DWR  31.354193 -7.748089            Baba Anje
# ...                 ...        ...       ...                  ...
# 22219           Artisan  39.032719 -8.449625           Kwamajambo
# 66888              TCRS  31.226952 -6.283132              Shuleni
# 31761  District Council  37.478867 -3.819237     Kirya Sec School
# 56224               HSW  34.099406 -1.670060          Kwe Kipande
# 9406                DWE  31.157624 -7.740882                Kiteo
#
#        num_private            basin  ... payment_type water_quality  \
# id                                   ...
# 29083            0    Lake Victoria  ...   per bucket       unknown
# 63695            0         Internal  ...      unknown       unknown
# 18842            0       Lake Rukwa  ...    never pay       unknown
# 17360            0  Lake Tanganyika  ...     annually       unknown
# 20279            0       Lake Rukwa  ...     annually       unknown
# ...            ...              ...  ...          ...           ...
# 22219            0           Rufiji  ...      unknown       unknown
# 66888            0       Lake Rukwa  ...   on failure       unknown
# 31761            0          Pangani  ...     annually       unknown
# 56224            0    Lake Victoria  ...      monthly       unknown
# 9406             0       Lake Rukwa  ...      unknown       unknown
#
#        quality_group  quantity quantity_group        source   source_type  \
# id
# 29083        unknown    enough         enough   machine dbh      borehole
# 63695        unknown    enough         enough   machine dbh      borehole
# 18842        unknown    enough         enough         river    river/lake
# 17360        unknown    enough         enough         river    river/lake
# 20279        unknown    enough         enough         river    river/lake
# ...              ...       ...            ...           ...           ...
# 22219        unknown    enough         enough  shallow well  shallow well
# 66888        unknown    enough         enough   machine dbh      borehole
# 31761        unknown    enough         enough           dam           dam
# 56224        unknown    enough         enough  shallow well  shallow well
# 9406         unknown    enough         enough   machine dbh      borehole
#
#       source_class              waterpoint_type waterpoint_type_group
# id
# 29083  groundwater  communal standpipe multiple    communal standpipe
# 63695  groundwater                    hand pump             hand pump
# 18842      surface           communal standpipe    communal standpipe
# 17360      surface  communal standpipe multiple    communal standpipe
# 20279      surface           communal standpipe    communal standpipe
# ...            ...                          ...                   ...
# 22219  groundwater                    hand pump             hand pump
# 66888  groundwater                    hand pump             hand pump
# 31761      surface           communal standpipe    communal standpipe
# 56224  groundwater                    hand pump             hand pump
# 9406   groundwater                    hand pump             hand pump
#
# [131 rows x 39 columns]

# %%
# Quantidade:

enoughWater[unknownQuality].quality_group.value_counts()[0]
# Out:
# 131

# %%
# Nome e localização:

enoughWater[unknownQuality][["wpt_name","latitude","longitude"]]
# Out:
#                   wpt_name  latitude  longitude
# id
# 29083             Kwa Shij -3.009659  33.079504
# 63695  Kwa Ismail Mnyankwe -4.742124  34.644989
# 18842      Shule Ya Msingi -7.687096  31.352875
# 17360           Kwa Elnazi -4.248860  30.074538
# 20279            Baba Anje -7.748089  31.354193
# ...                    ...       ...        ...
# 22219           Kwamajambo -8.449625  39.032719
# 66888              Shuleni -6.283132  31.226952
# 31761     Kirya Sec School -3.819237  37.478867
# 56224          Kwe Kipande -1.670060  34.099406
# 9406                 Kiteo -7.740882  31.157624
#
# [131 rows x 3 columns]

# %% [markdown]
# <br/><br/><br/>
# ### Qual é a média de quantidade de água em todas as minas?

# %%
### Quarta resolução

# %% [markdown]
# <br/><br/><br/>
# ### Quais são as minas mais velhas do data frame? Qual é a qualidade da água delas?

# %%
### Há várias minas com ano de construção igual a zero

nonInformedConstructionYear = data["construction_year"] == 0;
data[nonInformedConstructionYear]
# Out:
#        amount_tsh date_recorded                  funder  gps_height  \
# id
# 19728         0.0    2011-07-13             Action In A           0
# 19816         0.0    2012-10-01                    Dwsp           0
# 54551         0.0    2012-10-09                   Rwssp           0
# 53934         0.0    2012-11-03                Wateraid           0
# 46144         0.0    2011-08-03             Isingiro Ho           0
# ...           ...           ...                     ...         ...
# 72148         0.0    2011-07-10                 Concern           0
# 40607         0.0    2011-04-15  Government Of Tanzania           0
# 48348         0.0    2012-10-27                 Private           0
# 37057         0.0    2011-04-11                     NaN           0
# 31282         0.0    2011-03-08                   Malec           0
#
#         installer  longitude  latitude           wpt_name  num_private  \
# id
# 19728     Artisan  31.130847 -1.825359            Shuleni            0
# 19816        DWSP  33.362410 -3.766365         Kwa Ngomho            0
# 54551         DWE  32.620617 -4.226198       Tushirikiane            0
# 53934   Water Aid  32.711100 -5.146712  Kwa Ramadhan Musa            0
# 46144     Artisan  30.626991 -1.257051            Kwapeto            0
# ...           ...        ...       ...                ...          ...
# 72148     CONCERN  30.667805 -2.483710           Chamkube            0
# 40607  Government  33.009440 -8.520888     Benard Charles            0
# 48348     Private  33.866852 -4.287410          Kwa Peter            0
# 37057         NaN  34.017087 -8.750434            Mashine            0
# 31282        Musa  35.861315 -6.378573             Mshoro            0
#
#                  basin  ... payment_type water_quality  quality_group  \
# id                      ...
# 19728    Lake Victoria  ...    never pay          soft           good
# 19816         Internal  ...    never pay          soft           good
# 54551  Lake Tanganyika  ...      unknown         milky          milky
# 53934  Lake Tanganyika  ...    never pay         salty          salty
# 46144    Lake Victoria  ...    never pay          soft           good
# ...                ...  ...          ...           ...            ...
# 72148    Lake Victoria  ...    never pay          soft           good
# 40607       Lake Rukwa  ...    never pay          soft           good
# 48348         Internal  ...   per bucket          soft           good
# 37057           Rufiji  ...      monthly      fluoride       fluoride
# 31282           Rufiji  ...    never pay          soft           good
#
#            quantity quantity_group                source  \
# id
# 19728      seasonal       seasonal  rainwater harvesting
# 19816        enough         enough           machine dbh
# 54551        enough         enough          shallow well
# 53934      seasonal       seasonal           machine dbh
# 46144        enough         enough          shallow well
# ...             ...            ...                   ...
# 72148  insufficient   insufficient                spring
# 40607        enough         enough                spring
# 48348  insufficient   insufficient                   dam
# 37057        enough         enough           machine dbh
# 31282  insufficient   insufficient          shallow well
#
#                 source_type source_class     waterpoint_type  \
# id
# 19728  rainwater harvesting      surface  communal standpipe
# 19816              borehole  groundwater           hand pump
# 54551          shallow well  groundwater           hand pump
# 53934              borehole  groundwater           hand pump
# 46144          shallow well  groundwater           hand pump
# ...                     ...          ...                 ...
# 72148                spring  groundwater  communal standpipe
# 40607                spring  groundwater  communal standpipe
# 48348                   dam      surface               other
# 37057              borehole  groundwater           hand pump
# 31282          shallow well  groundwater           hand pump
#
#       waterpoint_type_group
# id
# 19728    communal standpipe
# 19816             hand pump
# 54551             hand pump
# 53934             hand pump
# 46144             hand pump
# ...                     ...
# 72148    communal standpipe
# 40607    communal standpipe
# 48348                 other
# 37057             hand pump
# 31282             hand pump
#
# [20709 rows x 39 columns]

# %%
# Obtendo ano mais antigo registrado:
informedConstructionYear = data["construction_year"] > 0;
oldestYear = data[informedConstructionYear].sort_values(by="construction_year").construction_year.min();
oldestYear
# Out:
# 1960

# %%
# Obtendo a quantidade de minas construídas no ano mais antigo:
builtInOldestYear = data.construction_year == oldestYear
data[builtInOldestYear].construction_year.count()
# Out:
# 102

# %%
# Obtendo a qualidade de água delas:

data[builtInOldestYear].groupby("water_quality")[["water_quality"]].describe()
# Out:
#               water_quality
#                       count unique       top freq
# water_quality
# fluoride                  5      1  fluoride    5
# salty                     5      1     salty    5
# soft                     42      1      soft   42
# unknown                  50      1   unknown   50

# %% [markdown]
# <br/><br/><br/>
# ### Quais são as minas com qualidade de água desconhecida?

# %%
### Sexta resolução

# %% [markdown]
# <br/><br/><br/><br/>
# ## Conclusão

# %% [markdown]
# Texto com conclusão do trabalho
#
# <br/><br/><br/><br/>

# %% [markdown]
# ### Esse material foi produzido com base no material de Thais Rodrigues Neubauer
