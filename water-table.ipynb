# %% [markdown]
# <img src="http://sonetodigital.com.br/adm/wp-content/uploads/2018/12/logo-fiap.png" width="150" align="left"/>
#
# <br/><br/>
#
# <font size=5 color="#ed145b"><b> Sistemas para internet </b></font><font size=5 color="#ed145b"> - Inteligência Artificial e Machine Learning  | NAC 01 </font>
#
# <font size=4 color="#ed145b"> Profa. Thais Rodrigues Neubauer</font>
# <br/><br/>
# <font size=4 color="#ed145b"> Grupo Cative: </font> <br/>
# <font size=3 color="#000"> Abraão RM: 83983</font><br/>
# <font size=3 color="#000"> Iago RM: </font><br/>
# <font size=3 color="#000"> Nicolas RM: </font><br/>
# <font size=3 color="#000"> Luis RM: </font><br/>
# <font size=3 color="#000"> Rodrigo RM: 83888 </font><br/>
# <font size=3 color="#000"> Geovanne RM: </font>

# %% [markdown]
# ## Título da avaliação
#
# Descrição falando sobre avaliação

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("pumpit.csv", index_col=0)

# %%
data
# Out:
#        amount_tsh date_recorded           funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14            Roman        1390         Roman
# 8776          0.0    2013-03-06          Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25     Lottery Club         686  World vision
# 67743         0.0    2013-01-28           Unicef         263        UNICEF
# 19728         0.0    2011-07-13      Action In A           0       Artisan
# ...           ...           ...              ...         ...           ...
# 60739        10.0    2013-05-03  Germany Republi        1210           CES
# 27263      4700.0    2011-05-07      Cefa-njombe        1212          Cefa
# 37057         0.0    2011-04-11              NaN           0           NaN
# 31282         0.0    2011-03-08            Malec           0          Musa
# 26348         0.0    2011-03-23       World Bank         191         World
#
#        longitude   latitude              wpt_name  num_private  \
# id
# 69572  34.938093  -9.856322                  none            0
# 8776   34.698766  -2.147466              Zahanati            0
# 34310  37.460664  -3.821329           Kwa Mahundi            0
# 67743  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728  31.130847  -1.825359               Shuleni            0
# ...          ...        ...                   ...          ...
# 60739  37.169807  -3.253847   Area Three Namba 27            0
# 27263  35.249991  -9.070629     Kwa Yahona Kuvala            0
# 37057  34.017087  -8.750434               Mashine            0
# 31282  35.861315  -6.378573                Mshoro            0
# 26348  38.104048  -6.747464       Kwa Mzee Lugawa            0
#
#                          basin  ... payment_type water_quality  quality_group  \
# id                              ...
# 69572               Lake Nyasa  ...     annually          soft           good
# 8776             Lake Victoria  ...    never pay          soft           good
# 34310                  Pangani  ...   per bucket          soft           good
# 67743  Ruvuma / Southern Coast  ...    never pay          soft           good
# 19728            Lake Victoria  ...    never pay          soft           good
# ...                        ...  ...          ...           ...            ...
# 60739                  Pangani  ...   per bucket          soft           good
# 27263                   Rufiji  ...     annually          soft           good
# 37057                   Rufiji  ...      monthly      fluoride       fluoride
# 31282                   Rufiji  ...    never pay          soft           good
# 26348              Wami / Ruvu  ...   on failure         salty          salty
#
#            quantity quantity_group                source  \
# id
# 69572        enough         enough                spring
# 8776   insufficient   insufficient  rainwater harvesting
# 34310        enough         enough                   dam
# 67743           dry            dry           machine dbh
# 19728      seasonal       seasonal  rainwater harvesting
# ...             ...            ...                   ...
# 60739        enough         enough                spring
# 27263        enough         enough                 river
# 37057        enough         enough           machine dbh
# 31282  insufficient   insufficient          shallow well
# 26348        enough         enough          shallow well
#
#                 source_type source_class              waterpoint_type  \
# id
# 69572                spring  groundwater           communal standpipe
# 8776   rainwater harvesting      surface           communal standpipe
# 34310                   dam      surface  communal standpipe multiple
# 67743              borehole  groundwater  communal standpipe multiple
# 19728  rainwater harvesting      surface           communal standpipe
# ...                     ...          ...                          ...
# 60739                spring  groundwater           communal standpipe
# 27263            river/lake      surface           communal standpipe
# 37057              borehole  groundwater                    hand pump
# 31282          shallow well  groundwater                    hand pump
# 26348          shallow well  groundwater                    hand pump
#
#       waterpoint_type_group
# id
# 69572    communal standpipe
# 8776     communal standpipe
# 34310    communal standpipe
# 67743    communal standpipe
# 19728    communal standpipe
# ...                     ...
# 60739    communal standpipe
# 27263    communal standpipe
# 37057             hand pump
# 31282             hand pump
# 26348             hand pump
#
# [59400 rows x 39 columns]

# %% [markdown]
# <br/><br/><br/>
# ### Quais minas estão sem água e o possivel motivo?

# %%
## Verificando opções e quantidade
noWater = data['quantity'].value_counts()
noWater
# Out:
# enough          33186
# insufficient    15129
# dry              6246
# seasonal         4050
# unknown           789
# Name: quantity, dtype: int64

# %%
## Fazendo filtro para quantity == dry
dryWaterMask = data.quantity == "dry"
dryWater = data[dryWaterMask]
dryWater
# Out:
#        amount_tsh date_recorded        funder  gps_height  \
# id
# 67743         0.0    2013-01-28        Unicef         263
# 48451       500.0    2011-07-04        Unicef        1703
# 58155         0.0    2011-09-04        Unicef        1656
# 67359         0.0    2011-07-16        Danida           0
# 19282         0.0    2013-01-15           NaN        1642
# ...           ...           ...           ...         ...
# 58233       100.0    2011-04-20           Adb        1583
# 32775         0.0    2011-01-08  Kkkt_makwale           0
# 46563         0.0    2013-02-19           NaN        1635
# 34716         0.0    2013-02-03           NaN        1581
# 30647      6000.0    2011-03-14         Roman        1439
#
#                   installer  longitude   latitude              wpt_name  \
# id
# 67743                UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu
# 48451                   DWE  34.642439  -9.106185       Kwa John Mtenzi
# 58155                   DWE  34.569266  -9.085515       Kwa Rose Chaula
# 67359    Central government  33.854345  -9.638520      Office Ya Kijiji
# 19282                   NaN  34.967789  -4.628921          Mvae Primary
# ...                     ...        ...        ...                   ...
# 58233                   DWE  35.287752  -9.390577  Kwa Zefania Mgombele
# 32775  KKKT _ Konde and DWE  33.993468  -9.441295            Kwa Tilani
# 46563                   NaN  34.971841  -5.098362               Shabani
# 34716                   NaN  34.821039  -5.076258               Nasingo
# 30647                 Roman  34.942101  -9.849198                  none
#
#        num_private                    basin  ... payment_type water_quality  \
# id                                           ...
# 67743            0  Ruvuma / Southern Coast  ...    never pay          soft
# 48451            0                   Rufiji  ...      monthly          soft
# 58155            0                   Rufiji  ...   on failure          soft
# 67359            0               Lake Nyasa  ...    never pay          soft
# 19282            0                 Internal  ...      unknown       unknown
# ...            ...                      ...  ...          ...           ...
# 58233            0                   Rufiji  ...   per bucket          soft
# 32775            0               Lake Nyasa  ...    never pay          soft
# 46563            0                 Internal  ...      unknown       unknown
# 34716            0                 Internal  ...      unknown       unknown
# 30647            0               Lake Nyasa  ...     annually          soft
#
#        quality_group  quantity quantity_group        source   source_type  \
# id
# 67743           good       dry            dry   machine dbh      borehole
# 48451           good       dry            dry         river    river/lake
# 58155           good       dry            dry         river    river/lake
# 67359           good       dry            dry        spring        spring
# 19282        unknown       dry            dry   machine dbh      borehole
# ...              ...       ...            ...           ...           ...
# 58233           good       dry            dry        spring        spring
# 32775           good       dry            dry        spring        spring
# 46563        unknown       dry            dry  shallow well  shallow well
# 34716        unknown       dry            dry  shallow well  shallow well
# 30647           good       dry            dry        spring        spring
#
#       source_class              waterpoint_type waterpoint_type_group
# id
# 67743  groundwater  communal standpipe multiple    communal standpipe
# 48451      surface           communal standpipe    communal standpipe
# 58155      surface           communal standpipe    communal standpipe
# 67359  groundwater           communal standpipe    communal standpipe
# 19282  groundwater           communal standpipe    communal standpipe
# ...            ...                          ...                   ...
# 58233  groundwater           communal standpipe    communal standpipe
# 32775  groundwater           communal standpipe    communal standpipe
# 46563  groundwater                    hand pump             hand pump
# 34716  groundwater                        other                 other
# 30647  groundwater           communal standpipe    communal standpipe
#
# [6246 rows x 39 columns]

# %%
## Verificando possivel motivo sendo pagamento
noPayment = dryWater['payment_type'].value_counts()
noPayment
## 50% nunca foram pagas
# Out:
# never pay     3133
# unknown       1570
# per bucket     583
# monthly        362
# on failure     347
# annually       179
# other           72
# Name: payment_type, dtype: int64

# %%
## Analisando as que nunca foram pagas
noPaymentMask = data.payment_type == "never pay"
dryWaterPayment = dryWater[NoPaymentMask]
dryWaterPayment
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#        amount_tsh date_recorded                   funder  gps_height  \
# id
# 67743         0.0    2013-01-28                   Unicef         263
# 67359         0.0    2011-07-16                   Danida           0
# 19308         0.0    2011-08-18                Dwe/norad        1545
# 9417          0.0    2011-07-14                   Sawaka           0
# 22108         0.0    2011-07-31   Government Of Tanzania           0
# ...           ...           ...                      ...         ...
# 70299         0.0    2011-07-16                   Danida           0
# 37867         0.0    2011-07-24                    Brown           0
# 45357         0.0    2013-12-02  Sangea District Council         847
# 46775         0.0    2013-01-20   Government Of Tanzania        1521
# 32775         0.0    2011-01-08             Kkkt_makwale           0
#
#                   installer  longitude   latitude              wpt_name  \
# id
# 67743                UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu
# 67359    Central government  33.854345  -9.638520      Office Ya Kijiji
# 19308                   DWE  32.046835  -8.571661            Kwa Kobelo
# 9417                Artisan  30.983023  -1.680654                Sawaka
# 22108                   DWE  30.716090  -1.285780              Kwashuza
# ...                     ...        ...        ...                   ...
# 70299    Central government  33.908040  -9.690655    Kwa Obed Mwakyonde
# 37867                 brown  33.809813  -9.495367  Kwa Brown Mwalutambi
# 45357  Sangea District Coun  35.798121 -10.725160         Kwa Inglibeth
# 46775            GOVERNMENT  34.784036  -4.828426              Malezi 2
# 32775  KKKT _ Konde and DWE  33.993468  -9.441295            Kwa Tilani
#
#        num_private                    basin  ... payment_type water_quality  \
# id                                           ...
# 67743            0  Ruvuma / Southern Coast  ...    never pay          soft
# 67359            0               Lake Nyasa  ...    never pay          soft
# 19308            0               Lake Rukwa  ...    never pay          soft
# 9417             0            Lake Victoria  ...    never pay          soft
# 22108            0            Lake Victoria  ...    never pay          soft
# ...            ...                      ...  ...          ...           ...
# 70299            0               Lake Nyasa  ...    never pay          soft
# 37867            0               Lake Nyasa  ...    never pay          soft
# 45357            0  Ruvuma / Southern Coast  ...    never pay          soft
# 46775            0                 Internal  ...    never pay          soft
# 32775            0               Lake Nyasa  ...    never pay          soft
#
#        quality_group  quantity quantity_group                source  \
# id
# 67743           good       dry            dry           machine dbh
# 67359           good       dry            dry                spring
# 19308           good       dry            dry                 river
# 9417            good       dry            dry  rainwater harvesting
# 22108           good       dry            dry                spring
# ...              ...       ...            ...                   ...
# 70299           good       dry            dry                spring
# 37867           good       dry            dry                spring
# 45357           good       dry            dry          shallow well
# 46775           good       dry            dry           machine dbh
# 32775           good       dry            dry                spring
#
#                 source_type source_class              waterpoint_type  \
# id
# 67743              borehole  groundwater  communal standpipe multiple
# 67359                spring  groundwater           communal standpipe
# 19308            river/lake      surface           communal standpipe
# 9417   rainwater harvesting      surface           communal standpipe
# 22108                spring  groundwater                        other
# ...                     ...          ...                          ...
# 70299                spring  groundwater           communal standpipe
# 37867                spring  groundwater           communal standpipe
# 45357          shallow well  groundwater                    hand pump
# 46775              borehole  groundwater                    hand pump
# 32775                spring  groundwater           communal standpipe
#
#       waterpoint_type_group
# id
# 67743    communal standpipe
# 67359    communal standpipe
# 19308    communal standpipe
# 9417     communal standpipe
# 22108                 other
# ...                     ...
# 70299    communal standpipe
# 37867    communal standpipe
# 45357             hand pump
# 46775             hand pump
# 32775    communal standpipe
#
# [3133 rows x 39 columns]

# %%
## Analisando possivel causa de nunca serem pagas como fontes subterraneas
wtSource = dryWaterPayment['source_class'].value_counts()
wtSource
# Out:
# groundwater    2655
# surface         463
# unknown          15
# Name: source_class, dtype: int64

# %%
## Verificando os dados das fontes subterraneas
wtSourceMask = data.source_class == "groundwater"
dryWaterPayment[wtSourceMask]
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#        amount_tsh date_recorded                   funder  gps_height  \
# id
# 67743         0.0    2013-01-28                   Unicef         263
# 67359         0.0    2011-07-16                   Danida           0
# 22108         0.0    2011-07-31   Government Of Tanzania           0
# 41743         0.0    2011-08-04   Government Of Tanzania          98
# 69525         0.0    2012-10-11                      Dwe           0
# ...           ...           ...                      ...         ...
# 70299         0.0    2011-07-16                   Danida           0
# 37867         0.0    2011-07-24                    Brown           0
# 45357         0.0    2013-12-02  Sangea District Council         847
# 46775         0.0    2013-01-20   Government Of Tanzania        1521
# 32775         0.0    2011-01-08             Kkkt_makwale           0
#
#                   installer  longitude   latitude              wpt_name  \
# id
# 67743                UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu
# 67359    Central government  33.854345  -9.638520      Office Ya Kijiji
# 22108                   DWE  30.716090  -1.285780              Kwashuza
# 41743                   DWE  39.042983  -4.994237              Kwa Tate
# 69525                   DWE  32.071081  -5.067269         Kitega Uchumi
# ...                     ...        ...        ...                   ...
# 70299    Central government  33.908040  -9.690655    Kwa Obed Mwakyonde
# 37867                 brown  33.809813  -9.495367  Kwa Brown Mwalutambi
# 45357  Sangea District Coun  35.798121 -10.725160         Kwa Inglibeth
# 46775            GOVERNMENT  34.784036  -4.828426              Malezi 2
# 32775  KKKT _ Konde and DWE  33.993468  -9.441295            Kwa Tilani
#
#        num_private                    basin  ... payment_type water_quality  \
# id                                           ...
# 67743            0  Ruvuma / Southern Coast  ...    never pay          soft
# 67359            0               Lake Nyasa  ...    never pay          soft
# 22108            0            Lake Victoria  ...    never pay          soft
# 41743            0                  Pangani  ...    never pay          soft
# 69525            0          Lake Tanganyika  ...    never pay          soft
# ...            ...                      ...  ...          ...           ...
# 70299            0               Lake Nyasa  ...    never pay          soft
# 37867            0               Lake Nyasa  ...    never pay          soft
# 45357            0  Ruvuma / Southern Coast  ...    never pay          soft
# 46775            0                 Internal  ...    never pay          soft
# 32775            0               Lake Nyasa  ...    never pay          soft
#
#        quality_group  quantity quantity_group        source   source_type  \
# id
# 67743           good       dry            dry   machine dbh      borehole
# 67359           good       dry            dry        spring        spring
# 22108           good       dry            dry        spring        spring
# 41743           good       dry            dry  shallow well  shallow well
# 69525           good       dry            dry   machine dbh      borehole
# ...              ...       ...            ...           ...           ...
# 70299           good       dry            dry        spring        spring
# 37867           good       dry            dry        spring        spring
# 45357           good       dry            dry  shallow well  shallow well
# 46775           good       dry            dry   machine dbh      borehole
# 32775           good       dry            dry        spring        spring
#
#       source_class              waterpoint_type waterpoint_type_group
# id
# 67743  groundwater  communal standpipe multiple    communal standpipe
# 67359  groundwater           communal standpipe    communal standpipe
# 22108  groundwater                        other                 other
# 41743  groundwater                        other                 other
# 69525  groundwater                    hand pump             hand pump
# ...            ...                          ...                   ...
# 70299  groundwater           communal standpipe    communal standpipe
# 37867  groundwater           communal standpipe    communal standpipe
# 45357  groundwater                    hand pump             hand pump
# 46775  groundwater                    hand pump             hand pump
# 32775  groundwater           communal standpipe    communal standpipe
#
# [2655 rows x 39 columns]

# %% [markdown]
# <br/><br/><br/>
# ### O tipo de pagamento interfere na qualidade da água?

# %%
### Segunda resolução
data['payment_type'].value_counts()
# Out:
# never pay     25348
# per bucket     8985
# monthly        8300
# unknown        8157
# on failure     3914
# annually       3642
# other          1054
# Name: payment_type, dtype: int64

# %%
perBucketMask = data.payment_type =='per bucket'
perBucket = data[perBucketMask]
perBucket
# Out:
#        amount_tsh date_recorded                  funder  gps_height  \
# id
# 34310        25.0    2013-02-25            Lottery Club         686
# 9944         20.0    2011-03-13     Mkinga Distric Coun           0
# 6696         50.0    2011-03-16      Private Individual         180
# 70238        25.0    2013-10-03               Ces(gmbh)         710
# 1843         20.0    2013-03-18  Government Of Tanzania        1007
# ...           ...           ...                     ...         ...
# 29940         0.0    2012-10-31                     Tlc           0
# 47002         6.0    2013-08-03               Ces(gmbh)        1383
# 26640       100.0    2013-03-12                       0          25
# 48348         0.0    2012-10-27                 Private           0
# 60739        10.0    2013-05-03         Germany Republi        1210
#
#           installer  longitude  latitude             wpt_name  num_private  \
# id
# 34310  World vision  37.460664 -3.821329          Kwa Mahundi            0
# 9944            DWE  39.172796 -4.765587               Tajiri            0
# 6696             WU  38.363555 -6.636104     Kituo Cha Maziwa            0
# 70238           DWE  37.420027 -3.476849           Kwa Lusina            0
# 1843            DWE  36.806079 -3.478559           Kwa Bariki            0
# ...             ...        ...       ...                  ...          ...
# 29940           TLC  32.058548 -5.052101     Kwa Mzee Kamanya            0
# 47002           DWE  37.454759 -3.323599       Kwa Luka Msaki            0
# 26640             0  39.176480 -6.957098           Kwa Maliba            0
# 48348       Private  33.866852 -4.287410            Kwa Peter            0
# 60739           CES  37.169807 -3.253847  Area Three Namba 27            0
#
#                  basin  ... payment_type water_quality  quality_group  \
# id                      ...
# 34310          Pangani  ...   per bucket          soft           good
# 9944           Pangani  ...   per bucket         salty          salty
# 6696       Wami / Ruvu  ...   per bucket          soft           good
# 70238          Pangani  ...   per bucket          soft           good
# 1843           Pangani  ...   per bucket          soft           good
# ...                ...  ...          ...           ...            ...
# 29940  Lake Tanganyika  ...   per bucket         salty          salty
# 47002          Pangani  ...   per bucket          soft           good
# 26640      Wami / Ruvu  ...   per bucket          soft           good
# 48348         Internal  ...   per bucket          soft           good
# 60739          Pangani  ...   per bucket          soft           good
#
#            quantity quantity_group        source   source_type source_class  \
# id
# 34310        enough         enough           dam           dam      surface
# 9944         enough         enough         other         other      unknown
# 6696         enough         enough         river    river/lake      surface
# 70238        enough         enough   machine dbh      borehole  groundwater
# 1843   insufficient   insufficient        spring        spring  groundwater
# ...             ...            ...           ...           ...          ...
# 29940  insufficient   insufficient  shallow well  shallow well  groundwater
# 47002        enough         enough        spring        spring  groundwater
# 26640        enough         enough   machine dbh      borehole  groundwater
# 48348  insufficient   insufficient           dam           dam      surface
# 60739        enough         enough        spring        spring  groundwater
#
#                    waterpoint_type waterpoint_type_group
# id
# 34310  communal standpipe multiple    communal standpipe
# 9944   communal standpipe multiple    communal standpipe
# 6696            communal standpipe    communal standpipe
# 70238           communal standpipe    communal standpipe
# 1843            communal standpipe    communal standpipe
# ...                            ...                   ...
# 29940                        other                 other
# 47002           communal standpipe    communal standpipe
# 26640           communal standpipe    communal standpipe
# 48348                        other                 other
# 60739           communal standpipe    communal standpipe
#
# [8985 rows x 39 columns]

# %%
perBucket['quality_group'].value_counts()
### Pagamentos por balde, a maioria dos lençóis ou é boa ou é salgada
# Out:
# good        7447
# salty       1381
# unknown       82
# colored       51
# milky         21
# fluoride       3
# Name: quality_group, dtype: int64

# %%
monthlyMask = data.payment_type == 'monthly'
monthly = data[monthlyMask]
monthly
# Out:
#        amount_tsh date_recorded                   funder  gps_height  \
# id
# 50495         0.0    2013-03-15  Lawatefuka Water Supply        1368
# 48451       500.0    2011-07-04                   Unicef        1703
# 48375       200.0    2011-02-27                      Twe        2216
# 37862       500.0    2013-11-03                      Isf         672
# 55012       500.0    2013-01-16                   Sobodo         200
# ...           ...           ...                      ...         ...
# 50998     40000.0    2011-08-03   Government Of Tanzania          54
# 38067       500.0    2011-03-21                       Rc        2101
# 34473       500.0    2012-11-03                    Jaica        1327
# 11164       500.0    2011-03-09               World Bank         351
# 37057         0.0    2011-04-11                      NaN           0
#
#                   installer  longitude  latitude               wpt_name  \
# id
# 50495  Lawatefuka water sup  37.092574 -3.181783   Kwa John Izack Mmari
# 48451                   DWE  34.642439 -9.106185        Kwa John Mtenzi
# 48375                   TWE  34.473430 -9.594990                   none
# 37862                   ISF  37.940029 -4.125595                Kinonga
# 55012           Kilolo Star  39.370777 -9.942532  Ruhoma Primary School
# ...                     ...        ...       ...                    ...
# 50998                   DWE  39.046942 -5.061494              Sekondari
# 38067                  ACRA  34.620387 -9.358405         Michael Msigwa
# 34473              JAICA CO  33.951681 -2.021854            Kwa Marunda
# 11164              ML appro  37.634053 -6.124830             Chimeredya
# 37057                   NaN  34.017087 -8.750434                Mashine
#
#        num_private                    basin  ... payment_type water_quality  \
# id                                           ...
# 50495            0                  Pangani  ...      monthly          soft
# 48451            0                   Rufiji  ...      monthly          soft
# 48375            0               Lake Nyasa  ...      monthly          soft
# 37862            0                  Pangani  ...      monthly          soft
# 55012            0  Ruvuma / Southern Coast  ...      monthly          soft
# ...            ...                      ...  ...          ...           ...
# 50998            0                  Pangani  ...      monthly          soft
# 38067            0                   Rufiji  ...      monthly          soft
# 34473            0            Lake Victoria  ...      monthly         salty
# 11164            0              Wami / Ruvu  ...      monthly          soft
# 37057            0                   Rufiji  ...      monthly      fluoride
#
#        quality_group  quantity quantity_group       source  source_type  \
# id
# 50495           good    enough         enough       spring       spring
# 48451           good       dry            dry        river   river/lake
# 48375           good    enough         enough       spring       spring
# 37862           good    enough         enough        river   river/lake
# 55012           good    enough         enough  machine dbh     borehole
# ...              ...       ...            ...          ...          ...
# 50998           good    enough         enough        river   river/lake
# 38067           good    enough         enough       spring       spring
# 34473          salty    enough         enough  machine dbh     borehole
# 11164           good    enough         enough  machine dbh     borehole
# 37057       fluoride    enough         enough  machine dbh     borehole
#
#       source_class     waterpoint_type waterpoint_type_group
# id
# 50495  groundwater  communal standpipe    communal standpipe
# 48451      surface  communal standpipe    communal standpipe
# 48375  groundwater  communal standpipe    communal standpipe
# 37862      surface  communal standpipe    communal standpipe
# 55012  groundwater           hand pump             hand pump
# ...            ...                 ...                   ...
# 50998      surface  communal standpipe    communal standpipe
# 38067  groundwater  communal standpipe    communal standpipe
# 34473  groundwater           hand pump             hand pump
# 11164  groundwater  communal standpipe    communal standpipe
# 37057  groundwater           hand pump             hand pump
#
# [8300 rows x 39 columns]

# %%
monthly['quality_group'].value_counts()
### Nota-se que as minas de água com pagamento mensal em dia a qualidade da água é boa
# Out:
# good        7834
# salty        371
# unknown       37
# colored       28
# milky         19
# fluoride      11
# Name: quality_group, dtype: int64

# %%
unknownPaymentMask = data.payment_type == 'unknown'
unknownPayment = data[unknownPaymentMask]
unknownPayment
# Out:
#        amount_tsh date_recorded                    funder  gps_height  \
# id
# 54551         0.0    2012-10-09                     Rwssp           0
# 6091          0.0    2013-02-10                      Dwsp           0
# 51058         0.0    2013-01-21  African Development Bank        1645
# 22308         0.0    2013-02-25    Government Of Tanzania        1273
# 25            0.0    2013-02-11    Government Of Tanzania        1348
# ...           ...           ...                       ...         ...
# 9406          0.0    2011-07-18                        No        1667
# 46563         0.0    2013-02-19                       NaN        1635
# 34716         0.0    2013-02-03                       NaN        1581
# 44616         0.0    2013-01-19                World Bank          11
# 72559         0.0    2013-01-29                     Kidep        1414
#
#         installer  longitude      latitude            wpt_name  num_private  \
# id
# 54551         DWE  32.620617 -4.226198e+00        Tushirikiane            0
# 6091          DWE   0.000000 -2.000000e-08            Muungano            0
# 51058         DWE  29.747066 -4.495568e+00             Kamsasa            0
# 22308         DWE  37.422751 -3.317536e+00           Kwa Tukai            0
# 25            DWE  30.613305 -3.894561e+00             Mkuyuni            0
# ...           ...        ...           ...                 ...          ...
# 9406          DWE  31.157624 -7.740882e+00               Kiteo            0
# 46563         NaN  34.971841 -5.098362e+00             Shabani            0
# 34716         NaN  34.821039 -5.076258e+00             Nasingo            0
# 44616  World bank  39.626009 -1.005750e+01             Shuleni            0
# 72559         DWE  30.692400 -3.593827e+00  Kwa Philipo Kibeba            0
#
#                          basin  ... payment_type water_quality  quality_group  \
# id                              ...
# 54551          Lake Tanganyika  ...      unknown         milky          milky
# 6091             Lake Victoria  ...      unknown       unknown        unknown
# 51058          Lake Tanganyika  ...      unknown          soft           good
# 22308                  Pangani  ...      unknown          soft           good
# 25             Lake Tanganyika  ...      unknown          soft           good
# ...                        ...  ...          ...           ...            ...
# 9406                Lake Rukwa  ...      unknown       unknown        unknown
# 46563                 Internal  ...      unknown       unknown        unknown
# 34716                 Internal  ...      unknown       unknown        unknown
# 44616  Ruvuma / Southern Coast  ...      unknown          soft           good
# 72559          Lake Tanganyika  ...      unknown          soft           good
#
#            quantity quantity_group                source  \
# id
# 54551        enough         enough          shallow well
# 6091        unknown        unknown          shallow well
# 51058        enough         enough                spring
# 22308        enough         enough                spring
# 25         seasonal       seasonal          shallow well
# ...             ...            ...                   ...
# 9406         enough         enough           machine dbh
# 46563           dry            dry          shallow well
# 34716           dry            dry          shallow well
# 44616        enough         enough  rainwater harvesting
# 72559  insufficient   insufficient                spring
#
#                 source_type source_class     waterpoint_type  \
# id
# 54551          shallow well  groundwater           hand pump
# 6091           shallow well  groundwater           hand pump
# 51058                spring  groundwater     improved spring
# 22308                spring  groundwater  communal standpipe
# 25             shallow well  groundwater           hand pump
# ...                     ...          ...                 ...
# 9406               borehole  groundwater           hand pump
# 46563          shallow well  groundwater           hand pump
# 34716          shallow well  groundwater               other
# 44616  rainwater harvesting      surface           hand pump
# 72559                spring  groundwater     improved spring
#
#       waterpoint_type_group
# id
# 54551             hand pump
# 6091              hand pump
# 51058       improved spring
# 22308    communal standpipe
# 25                hand pump
# ...                     ...
# 9406              hand pump
# 46563             hand pump
# 34716                 other
# 44616             hand pump
# 72559       improved spring
#
# [8157 rows x 39 columns]

# %%
unknownPayment['quality_group'].value_counts()
### Nota-se que quando o pagamento é desconhecido ou a qualidade é boa ou é desconhecida por igual
# Out:
# good        5838
# unknown     1073
# salty        629
# milky        505
# fluoride      68
# colored       44
# Name: quality_group, dtype: int64

# %%
onFailureMask = data.payment_type == 'on failure'
onFailure = data[onFailureMask]
onFailure
# Out:
#        amount_tsh date_recorded                   funder  gps_height  \
# id
# 50409       200.0    2013-02-18                   Danida        1062
# 58155         0.0    2011-09-04                   Unicef        1656
# 12402         0.0    2011-03-11                     Undp        1638
# 12796       500.0    2011-03-12   Government Of Tanzania        2469
# 12958         0.0    2012-10-22             World Vision           0
# ...           ...           ...                      ...         ...
# 512        2000.0    2013-01-29                     Tcrs        1497
# 52308         0.0    2013-02-03  Songea District Council        1037
# 8810          0.0    2011-09-04                   Unicef        1656
# 47527         0.0    2011-04-12                Rc Church           0
# 26348         0.0    2011-03-23               World Bank         191
#
#           installer  longitude   latitude           wpt_name  num_private  \
# id
# 50409        DANIDA  35.770258 -10.574175   Kwa Alid Nchimbi            0
# 58155           DWE  34.569266  -9.085515    Kwa Rose Chaula            0
# 12402           DWE  34.478356  -9.715910               none            0
# 12796         Commu  33.927902  -9.204649               none            0
# 12958  World Vision  33.345260  -3.838998            Shimasa            0
# ...             ...        ...        ...                ...          ...
# 512            TCRS  34.799452  -4.349604             Mitogo            0
# 52308           DWE  35.321152 -10.468370          Kwa Mvula            0
# 8810            DWE  34.594790  -9.072904  Kwa Yohane Mhanza            0
# 47527     RC Church  33.670049  -9.001535    Kwa Paval Dinno            0
# 26348         World  38.104048  -6.747464    Kwa Mzee Lugawa            0
#
#              basin  ... payment_type water_quality  quality_group  \
# id                  ...
# 50409   Lake Nyasa  ...   on failure          soft           good
# 58155       Rufiji  ...   on failure          soft           good
# 12402   Lake Nyasa  ...   on failure          soft           good
# 12796   Lake Nyasa  ...   on failure          soft           good
# 12958     Internal  ...   on failure          soft           good
# ...            ...  ...          ...           ...            ...
# 512       Internal  ...   on failure          soft           good
# 52308   Lake Nyasa  ...   on failure          soft           good
# 8810        Rufiji  ...   on failure          soft           good
# 47527   Lake Nyasa  ...   on failure          soft           good
# 26348  Wami / Ruvu  ...   on failure         salty          salty
#
#            quantity quantity_group        source   source_type source_class  \
# id
# 50409  insufficient   insufficient  shallow well  shallow well  groundwater
# 58155           dry            dry         river    river/lake      surface
# 12402      seasonal       seasonal        spring        spring  groundwater
# 12796        enough         enough        spring        spring  groundwater
# 12958        enough         enough   machine dbh      borehole  groundwater
# ...             ...            ...           ...           ...          ...
# 512          enough         enough  shallow well  shallow well  groundwater
# 52308        enough         enough        spring        spring  groundwater
# 8810         enough         enough         river    river/lake      surface
# 47527        enough         enough         river    river/lake      surface
# 26348        enough         enough  shallow well  shallow well  groundwater
#
#           waterpoint_type waterpoint_type_group
# id
# 50409           hand pump             hand pump
# 58155  communal standpipe    communal standpipe
# 12402  communal standpipe    communal standpipe
# 12796  communal standpipe    communal standpipe
# 12958  communal standpipe    communal standpipe
# ...                   ...                   ...
# 512             hand pump             hand pump
# 52308  communal standpipe    communal standpipe
# 8810   communal standpipe    communal standpipe
# 47527  communal standpipe    communal standpipe
# 26348           hand pump             hand pump
#
# [3914 rows x 39 columns]

# %%
onFailure['quality_group'].value_counts()
### Minas que estão em falência na maioria, suas águas são boas.
# Out:
# good        3650
# salty        181
# unknown       41
# milky         21
# colored       18
# fluoride       3
# Name: quality_group, dtype: int64

# %%
annuallyMask = data.payment_type == 'annually'
annually = data[annuallyMask]
annually
# Out:
#        amount_tsh date_recorded                  funder  gps_height installer  \
# id
# 69572      6000.0    2011-03-14                   Roman        1390     Roman
# 18274       500.0    2011-02-22                  Danida        1763     Danid
# 16583      4000.0    2011-02-20                    Cefa        1955      CEFA
# 18864      4000.0    2011-02-20                    Cefa        1982      CEFA
# 25182      1500.0    2011-04-04        District Council        2169       DWE
# ...           ...           ...                     ...         ...       ...
# 12375      6000.0    2011-02-23                     Twe        1933       TWE
# 73019      2000.0    2011-03-09  Government Of Tanzania        1977     Commu
# 15233      5000.0    2013-01-30                   Rudep        1137    Distri
# 30647      6000.0    2011-03-14                   Roman        1439     Roman
# 27263      4700.0    2011-05-07             Cefa-njombe        1212      Cefa
#
#        longitude  latitude           wpt_name  num_private       basin  ...  \
# id                                                                      ...
# 69572  34.938093 -9.856322               none            0  Lake Nyasa  ...
# 18274  34.508967 -9.894412               none            0  Lake Nyasa  ...
# 16583  35.890264 -8.224399               none            0      Rufiji  ...
# 18864  35.871413 -8.227563               none            0      Rufiji  ...
# 25182  34.441283 -9.189878  Kwa Bryson Msigwa            0      Rufiji  ...
# ...          ...       ...                ...          ...         ...  ...
# 12375  34.709522 -9.659056               none            0  Lake Nyasa  ...
# 73019  34.338899 -9.565553               none            0  Lake Nyasa  ...
# 15233  32.125024 -6.784358        Kwa Kadiega            0  Lake Rukwa  ...
# 30647  34.942101 -9.849198               none            0  Lake Nyasa  ...
# 27263  35.249991 -9.070629  Kwa Yahona Kuvala            0      Rufiji  ...
#
#       payment_type water_quality  quality_group  quantity quantity_group  \
# id
# 69572     annually          soft           good    enough         enough
# 18274     annually          soft           good    enough         enough
# 16583     annually          soft           good    enough         enough
# 18864     annually          soft           good    enough         enough
# 25182     annually          soft           good    enough         enough
# ...            ...           ...            ...       ...            ...
# 12375     annually          soft           good    enough         enough
# 73019     annually          soft           good    enough         enough
# 15233     annually          soft           good    enough         enough
# 30647     annually          soft           good       dry            dry
# 27263     annually          soft           good    enough         enough
#
#             source  source_type source_class     waterpoint_type  \
# id
# 69572       spring       spring  groundwater  communal standpipe
# 18274       spring       spring  groundwater  communal standpipe
# 16583        river   river/lake      surface  communal standpipe
# 18864       spring       spring  groundwater  communal standpipe
# 25182       spring       spring  groundwater  communal standpipe
# ...            ...          ...          ...                 ...
# 12375       spring       spring  groundwater  communal standpipe
# 73019       spring       spring  groundwater  communal standpipe
# 15233  machine dbh     borehole  groundwater           hand pump
# 30647       spring       spring  groundwater  communal standpipe
# 27263        river   river/lake      surface  communal standpipe
#
#       waterpoint_type_group
# id
# 69572    communal standpipe
# 18274    communal standpipe
# 16583    communal standpipe
# 18864    communal standpipe
# 25182    communal standpipe
# ...                     ...
# 12375    communal standpipe
# 73019    communal standpipe
# 15233             hand pump
# 30647    communal standpipe
# 27263    communal standpipe
#
# [3642 rows x 39 columns]

# %%
annually['quality_group'].value_counts()
### Minas que são pagas anualmente em sua maioria tem qualidade de água boa.
# Out:
# good        3384
# salty        164
# unknown       45
# fluoride      23
# milky         13
# colored       13
# Name: quality_group, dtype: int64

# %%
otherMask = data.payment_type == 'other'
other = data[otherMask]
other
# Out:
#        amount_tsh date_recorded                  funder  gps_height  \
# id
# 36957         0.0    2012-10-14            World Vision           0
# 35715         0.0    2013-02-27                  Hesawa        1565
# 68554       500.0    2013-02-11  Government Of Tanzania        1274
# 59902         0.0    2013-02-17             Netherlands           0
# 60371         0.0    2011-07-21                  Hesawa           0
# ...           ...           ...                     ...         ...
# 41929       450.0    2013-02-25         Germany Republi        1581
# 62177         0.0    2011-07-18                    Dwsp           0
# 48076       300.0    2013-02-26         Germany Republi        1341
# 31903         0.0    2012-11-04             Netherlands           0
# 49651         0.0    2012-10-29                   Rwssp           0
#
#           installer  longitude      latitude                     wpt_name  \
# id
# 36957  World vision  33.798106 -3.290194e+00                        Pamba
# 35715        HESAWA  34.657034 -1.888020e+00                     Machumbe
# 68554    Government  30.126681 -4.236378e+00                 Kwa Nyonyori
# 59902           DWE  33.697900 -3.269497e+00  Watumia Maji (Maji Ni Uhai)
# 60371        HESAWA  31.767301 -3.025106e+00                    Maendeleo
# ...             ...        ...           ...                          ...
# 41929           CES  37.204615 -3.187247e+00             Kwa Elinipa Lema
# 62177           DWE   0.000000 -2.000000e-08                       Wazazo
# 48076           CES  37.201218 -3.225780e+00              Kwa Zaitun Swai
# 31903           DWE  33.898670 -3.108308e+00                Mwashindike B
# 49651           DWE   0.000000 -2.000000e-08                   Nguvu Kazi
#
#        num_private            basin  ... payment_type water_quality  \
# id                                   ...
# 36957            0         Internal  ...        other          soft
# 35715            0    Lake Victoria  ...        other          soft
# 68554            0  Lake Tanganyika  ...        other          soft
# 59902            0         Internal  ...        other          soft
# 60371            0    Lake Victoria  ...        other          soft
# ...            ...              ...  ...          ...           ...
# 41929            0          Pangani  ...        other          soft
# 62177            0    Lake Victoria  ...        other          soft
# 48076            0          Pangani  ...        other          soft
# 31903            0    Lake Victoria  ...        other          soft
# 49651            0    Lake Victoria  ...        other          soft
#
#        quality_group      quantity quantity_group        source   source_type  \
# id
# 36957           good        enough         enough  shallow well  shallow well
# 35715           good  insufficient   insufficient  shallow well  shallow well
# 68554           good        enough         enough   machine dbh      borehole
# 59902           good        enough         enough  shallow well  shallow well
# 60371           good        enough         enough      hand dtw      borehole
# ...              ...           ...            ...           ...           ...
# 41929           good        enough         enough        spring        spring
# 62177           good        enough         enough  shallow well  shallow well
# 48076           good        enough         enough        spring        spring
# 31903           good        enough         enough  shallow well  shallow well
# 49651           good        enough         enough  shallow well  shallow well
#
#       source_class              waterpoint_type waterpoint_type_group
# id
# 36957  groundwater                    hand pump             hand pump
# 35715  groundwater                    hand pump             hand pump
# 68554  groundwater  communal standpipe multiple    communal standpipe
# 59902  groundwater                    hand pump             hand pump
# 60371  groundwater                    hand pump             hand pump
# ...            ...                          ...                   ...
# 41929  groundwater  communal standpipe multiple    communal standpipe
# 62177  groundwater                    hand pump             hand pump
# 48076  groundwater           communal standpipe    communal standpipe
# 31903  groundwater                    hand pump             hand pump
# 49651  groundwater                    hand pump             hand pump
#
# [1054 rows x 39 columns]

# %%
other['quality_group'].value_counts()
### Minas com outros tipos de pagamente em sua maioria possuem águas com qualidade boa
# Out:
# good        895
# salty       103
# unknown      35
# colored       9
# milky         8
# fluoride      4
# Name: quality_group, dtype: int64

# %%
neverPayMask = data.payment_type == 'never pay'
neverPay = data[neverPayMask]
neverPay
# Out:
#        amount_tsh date_recorded           funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14            Roman        1390         Roman
# 8776          0.0    2013-03-06          Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25     Lottery Club         686  World vision
# 67743         0.0    2013-01-28           Unicef         263        UNICEF
# 19728         0.0    2011-07-13      Action In A           0       Artisan
# ...           ...           ...              ...         ...           ...
# 60739        10.0    2013-05-03  Germany Republi        1210           CES
# 27263      4700.0    2011-05-07      Cefa-njombe        1212          Cefa
# 37057         0.0    2011-04-11              NaN           0           NaN
# 31282         0.0    2011-03-08            Malec           0          Musa
# 26348         0.0    2011-03-23       World Bank         191         World
#
#        longitude   latitude              wpt_name  num_private  \
# id
# 69572  34.938093  -9.856322                  none            0
# 8776   34.698766  -2.147466              Zahanati            0
# 34310  37.460664  -3.821329           Kwa Mahundi            0
# 67743  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728  31.130847  -1.825359               Shuleni            0
# ...          ...        ...                   ...          ...
# 60739  37.169807  -3.253847   Area Three Namba 27            0
# 27263  35.249991  -9.070629     Kwa Yahona Kuvala            0
# 37057  34.017087  -8.750434               Mashine            0
# 31282  35.861315  -6.378573                Mshoro            0
# 26348  38.104048  -6.747464       Kwa Mzee Lugawa            0
#
#                          basin  ... payment_type water_quality  quality_group  \
# id                              ...
# 69572               Lake Nyasa  ...    never pay          soft           good
# 8776             Lake Victoria  ...    never pay          soft           good
# 34310                  Pangani  ...    never pay          soft           good
# 67743  Ruvuma / Southern Coast  ...    never pay          soft           good
# 19728            Lake Victoria  ...    never pay          soft           good
# ...                        ...  ...          ...           ...            ...
# 60739                  Pangani  ...    never pay          soft           good
# 27263                   Rufiji  ...    never pay          soft           good
# 37057                   Rufiji  ...    never pay      fluoride       fluoride
# 31282                   Rufiji  ...    never pay          soft           good
# 26348              Wami / Ruvu  ...    never pay         salty          salty
#
#            quantity quantity_group                source  \
# id
# 69572        enough         enough                spring
# 8776   insufficient   insufficient  rainwater harvesting
# 34310        enough         enough                   dam
# 67743           dry            dry           machine dbh
# 19728      seasonal       seasonal  rainwater harvesting
# ...             ...            ...                   ...
# 60739        enough         enough                spring
# 27263        enough         enough                 river
# 37057        enough         enough           machine dbh
# 31282  insufficient   insufficient          shallow well
# 26348        enough         enough          shallow well
#
#                 source_type source_class              waterpoint_type  \
# id
# 69572                spring  groundwater           communal standpipe
# 8776   rainwater harvesting      surface           communal standpipe
# 34310                   dam      surface  communal standpipe multiple
# 67743              borehole  groundwater  communal standpipe multiple
# 19728  rainwater harvesting      surface           communal standpipe
# ...                     ...          ...                          ...
# 60739                spring  groundwater           communal standpipe
# 27263            river/lake      surface           communal standpipe
# 37057              borehole  groundwater                    hand pump
# 31282          shallow well  groundwater                    hand pump
# 26348          shallow well  groundwater                    hand pump
#
#       waterpoint_type_group
# id
# 69572    communal standpipe
# 8776     communal standpipe
# 34310    communal standpipe
# 67743    communal standpipe
# 19728    communal standpipe
# ...                     ...
# 60739    communal standpipe
# 27263    communal standpipe
# 37057             hand pump
# 31282             hand pump
# 26348             hand pump
#
# [59400 rows x 39 columns]

# %%
neverPay['quality_group'].value_counts()
### Minas que nunca foram pagas em sua maioria, a qualidade da água é boa.
# Out:
# good        50818
# salty        5195
# unknown      1876
# milky         804
# colored       490
# fluoride      217
# Name: quality_group, dtype: int64

# %%
### Conclusão:
## O tipo de pagamento não interefe na qualidade da água,
## pois nota-se que em todos os tipos de pagamento, a qualidade da água predominante é do tipo "good".

# %% [markdown]
# <br/><br/><br/>
# ### Quais minas estão com água o suficiente mas têm qualidade desconhecida?

# %%
### Terceira resolução
enoughWaterMask = data.quantity == "enough";
enoughWater = data[enoughWaterMask]
unknownQuality = enoughWater.water_quality == "unknown";
enoughWater[unknownQuality]
# Out:
#        amount_tsh date_recorded                         funder  gps_height  \
# id
# 29083         0.0    2011-08-04                        Mzee Sh           0
# 63695         0.0    2013-01-16                           Dfid        1481
# 18842         0.0    2011-07-22                             Co        1886
# 17360       500.0    2013-02-10                          Oxfam        1287
# 20279      1000.0    2011-07-23                             De        1916
# ...           ...           ...                            ...         ...
# 22219         0.0    2013-02-15                     World Bank         148
# 66888         0.0    2013-02-02                           Tcrs        1238
# 31761      7500.0    2013-02-15  Professor Ben Ohio University         680
# 56224       100.0    2012-10-17                            Hsw        1209
# 9406          0.0    2011-07-18                             No        1667
#
#               installer  longitude  latitude             wpt_name  \
# id
# 29083             ALLYS  33.079504 -3.009659             Kwa Shij
# 63695         WATER AID  34.644989 -4.742124  Kwa Ismail Mnyankwe
# 18842               DWE  31.352875 -7.687096      Shule Ya Msingi
# 17360             OXFAM  30.074538 -4.248860           Kwa Elnazi
# 20279               DWR  31.354193 -7.748089            Baba Anje
# ...                 ...        ...       ...                  ...
# 22219           Artisan  39.032719 -8.449625           Kwamajambo
# 66888              TCRS  31.226952 -6.283132              Shuleni
# 31761  District Council  37.478867 -3.819237     Kirya Sec School
# 56224               HSW  34.099406 -1.670060          Kwe Kipande
# 9406                DWE  31.157624 -7.740882                Kiteo
#
#        num_private            basin  ... payment_type water_quality  \
# id                                   ...
# 29083            0    Lake Victoria  ...   per bucket       unknown
# 63695            0         Internal  ...      unknown       unknown
# 18842            0       Lake Rukwa  ...    never pay       unknown
# 17360            0  Lake Tanganyika  ...     annually       unknown
# 20279            0       Lake Rukwa  ...     annually       unknown
# ...            ...              ...  ...          ...           ...
# 22219            0           Rufiji  ...      unknown       unknown
# 66888            0       Lake Rukwa  ...   on failure       unknown
# 31761            0          Pangani  ...     annually       unknown
# 56224            0    Lake Victoria  ...      monthly       unknown
# 9406             0       Lake Rukwa  ...      unknown       unknown
#
#        quality_group  quantity quantity_group        source   source_type  \
# id
# 29083        unknown    enough         enough   machine dbh      borehole
# 63695        unknown    enough         enough   machine dbh      borehole
# 18842        unknown    enough         enough         river    river/lake
# 17360        unknown    enough         enough         river    river/lake
# 20279        unknown    enough         enough         river    river/lake
# ...              ...       ...            ...           ...           ...
# 22219        unknown    enough         enough  shallow well  shallow well
# 66888        unknown    enough         enough   machine dbh      borehole
# 31761        unknown    enough         enough           dam           dam
# 56224        unknown    enough         enough  shallow well  shallow well
# 9406         unknown    enough         enough   machine dbh      borehole
#
#       source_class              waterpoint_type waterpoint_type_group
# id
# 29083  groundwater  communal standpipe multiple    communal standpipe
# 63695  groundwater                    hand pump             hand pump
# 18842      surface           communal standpipe    communal standpipe
# 17360      surface  communal standpipe multiple    communal standpipe
# 20279      surface           communal standpipe    communal standpipe
# ...            ...                          ...                   ...
# 22219  groundwater                    hand pump             hand pump
# 66888  groundwater                    hand pump             hand pump
# 31761      surface           communal standpipe    communal standpipe
# 56224  groundwater                    hand pump             hand pump
# 9406   groundwater                    hand pump             hand pump
#
# [131 rows x 39 columns]

# %%
# Quantidade:

enoughWater[unknownQuality].quality_group.value_counts()[0]
# Out:
# 131

# %%
# Nome e localização:

enoughWater[unknownQuality][["wpt_name","latitude","longitude"]]
# Out:
#                   wpt_name  latitude  longitude
# id
# 29083             Kwa Shij -3.009659  33.079504
# 63695  Kwa Ismail Mnyankwe -4.742124  34.644989
# 18842      Shule Ya Msingi -7.687096  31.352875
# 17360           Kwa Elnazi -4.248860  30.074538
# 20279            Baba Anje -7.748089  31.354193
# ...                    ...       ...        ...
# 22219           Kwamajambo -8.449625  39.032719
# 66888              Shuleni -6.283132  31.226952
# 31761     Kirya Sec School -3.819237  37.478867
# 56224          Kwe Kipande -1.670060  34.099406
# 9406                 Kiteo -7.740882  31.157624
#
# [131 rows x 3 columns]

# %% [markdown]
# <br/><br/><br/>
# ### Qual é a média de quantidade de água em todas as minas?

# %%
### Quarta resolução

# %% [markdown]
# <br/><br/><br/>
# ### Quais são as minas mais velhas do data frame? Qual é a qualidade da água delas?

# %%
### Há várias minas com ano de construção igual a zero

nonInformedConstructionYear = data["construction_year"] == 0;
data[nonInformedConstructionYear]
# Out:
#        amount_tsh date_recorded                  funder  gps_height  \
# id
# 19728         0.0    2011-07-13             Action In A           0
# 19816         0.0    2012-10-01                    Dwsp           0
# 54551         0.0    2012-10-09                   Rwssp           0
# 53934         0.0    2012-11-03                Wateraid           0
# 46144         0.0    2011-08-03             Isingiro Ho           0
# ...           ...           ...                     ...         ...
# 72148         0.0    2011-07-10                 Concern           0
# 40607         0.0    2011-04-15  Government Of Tanzania           0
# 48348         0.0    2012-10-27                 Private           0
# 37057         0.0    2011-04-11                     NaN           0
# 31282         0.0    2011-03-08                   Malec           0
#
#         installer  longitude  latitude           wpt_name  num_private  \
# id
# 19728     Artisan  31.130847 -1.825359            Shuleni            0
# 19816        DWSP  33.362410 -3.766365         Kwa Ngomho            0
# 54551         DWE  32.620617 -4.226198       Tushirikiane            0
# 53934   Water Aid  32.711100 -5.146712  Kwa Ramadhan Musa            0
# 46144     Artisan  30.626991 -1.257051            Kwapeto            0
# ...           ...        ...       ...                ...          ...
# 72148     CONCERN  30.667805 -2.483710           Chamkube            0
# 40607  Government  33.009440 -8.520888     Benard Charles            0
# 48348     Private  33.866852 -4.287410          Kwa Peter            0
# 37057         NaN  34.017087 -8.750434            Mashine            0
# 31282        Musa  35.861315 -6.378573             Mshoro            0
#
#                  basin  ... payment_type water_quality  quality_group  \
# id                      ...
# 19728    Lake Victoria  ...    never pay          soft           good
# 19816         Internal  ...    never pay          soft           good
# 54551  Lake Tanganyika  ...      unknown         milky          milky
# 53934  Lake Tanganyika  ...    never pay         salty          salty
# 46144    Lake Victoria  ...    never pay          soft           good
# ...                ...  ...          ...           ...            ...
# 72148    Lake Victoria  ...    never pay          soft           good
# 40607       Lake Rukwa  ...    never pay          soft           good
# 48348         Internal  ...   per bucket          soft           good
# 37057           Rufiji  ...      monthly      fluoride       fluoride
# 31282           Rufiji  ...    never pay          soft           good
#
#            quantity quantity_group                source  \
# id
# 19728      seasonal       seasonal  rainwater harvesting
# 19816        enough         enough           machine dbh
# 54551        enough         enough          shallow well
# 53934      seasonal       seasonal           machine dbh
# 46144        enough         enough          shallow well
# ...             ...            ...                   ...
# 72148  insufficient   insufficient                spring
# 40607        enough         enough                spring
# 48348  insufficient   insufficient                   dam
# 37057        enough         enough           machine dbh
# 31282  insufficient   insufficient          shallow well
#
#                 source_type source_class     waterpoint_type  \
# id
# 19728  rainwater harvesting      surface  communal standpipe
# 19816              borehole  groundwater           hand pump
# 54551          shallow well  groundwater           hand pump
# 53934              borehole  groundwater           hand pump
# 46144          shallow well  groundwater           hand pump
# ...                     ...          ...                 ...
# 72148                spring  groundwater  communal standpipe
# 40607                spring  groundwater  communal standpipe
# 48348                   dam      surface               other
# 37057              borehole  groundwater           hand pump
# 31282          shallow well  groundwater           hand pump
#
#       waterpoint_type_group
# id
# 19728    communal standpipe
# 19816             hand pump
# 54551             hand pump
# 53934             hand pump
# 46144             hand pump
# ...                     ...
# 72148    communal standpipe
# 40607    communal standpipe
# 48348                 other
# 37057             hand pump
# 31282             hand pump
#
# [20709 rows x 39 columns]

# %%
# Obtendo ano mais antigo registrado:
informedConstructionYear = data["construction_year"] > 0;
oldestYear = data[informedConstructionYear].sort_values(by="construction_year").construction_year.min();
oldestYear
# Out:
# 1960

# %%
# Obtendo a quantidade de minas construídas no ano mais antigo:
builtInOldestYear = data.construction_year == oldestYear
data[builtInOldestYear].construction_year.count()
# Out:
# 102

# %%
# Obtendo a qualidade de água delas:

data[builtInOldestYear].groupby("water_quality")[["water_quality"]].describe()
# Out:
#               water_quality
#                       count unique       top freq
# water_quality
# fluoride                  5      1  fluoride    5
# salty                     5      1     salty    5
# soft                     42      1      soft   42
# unknown                  50      1   unknown   50

# %% [markdown]
# <br/><br/><br/>
# ### Quais são os possiveis motivos da qualidade da água ser desconhecida?

# %%
### Sexta resolução

# %%
### Verificando a quantidade de minas com a qualidade de água desconhecida
waterQuality = data['water_quality'].value_counts()
waterQuality
# Out:
# soft                  50818
# salty                  4856
# unknown                1876
# milky                   804
# coloured                490
# salty abandoned         339
# fluoride                200
# fluoride abandoned       17
# Name: water_quality, dtype: int64

# %%
qualityUnknown = data[data['water_quality']=='unknown']['water_quality']

# %%
qualityUnknown.value_counts()
# Out:
# unknown    1876
# Name: water_quality, dtype: int64

# %%
### Filtro das aguas com qualidade desconhecida
unknownQualityMask = data.water_quality == "unknown"
unknownQuality = data[unknownQualityMask]
unknownQuality
# Out:
#        amount_tsh date_recorded                  funder  gps_height  \
# id
# 6091          0.0    2013-02-10                    Dwsp           0
# 19282         0.0    2013-01-15                     NaN        1642
# 32376         0.0    2011-08-01  Government Of Tanzania           0
# 51072         0.0    2013-02-09                     NaN        1415
# 21990       200.0    2011-03-05  Government Of Tanzania         303
# ...           ...           ...                     ...         ...
# 6450          0.0    2013-10-03                     NaN        1303
# 9406          0.0    2011-07-18                      No        1667
# 46563         0.0    2013-02-19                     NaN        1635
# 14796       200.0    2013-01-29                     NaN        1154
# 34716         0.0    2013-02-03                     NaN        1581
#
#         installer  longitude      latitude            wpt_name  num_private  \
# id
# 6091          DWE   0.000000 -2.000000e-08            Muungano            0
# 19282         NaN  34.967789 -4.628921e+00        Mvae Primary            0
# 32376  Government   0.000000 -2.000000e-08              Polisi            0
# 51072         NaN  34.621598 -5.173136e+00              Nyambi            0
# 21990         RWE  35.818981 -8.934950e+00         Kwampalanji            0
# ...           ...        ...           ...                 ...          ...
# 6450          NaN  36.900911 -3.111477e+00  Pentecoste Swidish            0
# 9406          DWE  31.157624 -7.740882e+00               Kiteo            0
# 46563         NaN  34.971841 -5.098362e+00             Shabani            0
# 14796         NaN  30.058731 -4.902633e+00      Village Office            0
# 34716         NaN  34.821039 -5.076258e+00             Nasingo            0
#
#                  basin  ... payment_type water_quality  quality_group  \
# id                      ...
# 6091     Lake Victoria  ...      unknown       unknown        unknown
# 19282         Internal  ...      unknown       unknown        unknown
# 32376    Lake Victoria  ...      unknown       unknown        unknown
# 51072         Internal  ...      unknown       unknown        unknown
# 21990           Rufiji  ...      monthly       unknown        unknown
# ...                ...  ...          ...           ...            ...
# 6450          Internal  ...      unknown       unknown        unknown
# 9406        Lake Rukwa  ...      unknown       unknown        unknown
# 46563         Internal  ...      unknown       unknown        unknown
# 14796  Lake Tanganyika  ...      monthly       unknown        unknown
# 34716         Internal  ...      unknown       unknown        unknown
#
#            quantity quantity_group        source   source_type source_class  \
# id
# 6091        unknown        unknown  shallow well  shallow well  groundwater
# 19282           dry            dry   machine dbh      borehole  groundwater
# 32376           dry            dry   machine dbh      borehole  groundwater
# 51072           dry            dry   machine dbh      borehole  groundwater
# 21990  insufficient   insufficient  shallow well  shallow well  groundwater
# ...             ...            ...           ...           ...          ...
# 6450        unknown        unknown        spring        spring  groundwater
# 9406         enough         enough   machine dbh      borehole  groundwater
# 46563           dry            dry  shallow well  shallow well  groundwater
# 14796       unknown        unknown       unknown         other      unknown
# 34716           dry            dry  shallow well  shallow well  groundwater
#
#                    waterpoint_type waterpoint_type_group
# id
# 6091                     hand pump             hand pump
# 19282           communal standpipe    communal standpipe
# 32376  communal standpipe multiple    communal standpipe
# 51072           communal standpipe    communal standpipe
# 21990                    hand pump             hand pump
# ...                            ...                   ...
# 6450            communal standpipe    communal standpipe
# 9406                     hand pump             hand pump
# 46563                    hand pump             hand pump
# 14796                        other                 other
# 34716                        other                 other
#
# [1876 rows x 39 columns]

# %%
### Verificando o motivo da qualidade da agua ser o tipo de pagamento

# %%
noPayment = unknownQuality['payment_type'].value_counts()
noPayment
## um pouco mais de 57% dessas águas com qualidade desconhecida, seu tipo de pagamento também é desconhecido
# Out:
# unknown       1073
# never pay      563
# per bucket      82
# annually        45
# on failure      41
# monthly         37
# other           35
# Name: payment_type, dtype: int64

# %%
### Verificando o motivo da qualidade ser desconhecida ser a classe da nascente
sourceClass = unknownQuality['source_class'].value_counts()
sourceClass

### Nota-se a qualidade da água é desconhecida é comum em lençois freáticos, devido à dificuldade de acesso nos mesmos.
# Out:
# groundwater    1556
# surface         277
# unknown          43
# Name: source_class, dtype: int64

# %%
### Verificando o motivo da qualidade da agua ser desconhecida ser o tipo da sua nascente
sourceType = unknownQuality['source_type'].value_counts()
sourceType
### A qualidade da água desconhecida é mais conhecida em lençóis rasos
# Out:
# shallow well            713
# borehole                647
# river/lake              200
# spring                  196
# rainwater harvesting     47
# other                    43
# dam                      30
# Name: source_type, dtype: int64

# %% [markdown]
# <br/><br/><br/><br/>
# ## Conclusão

# %% [markdown]
# Texto com conclusão do trabalho
#
# <br/><br/><br/><br/>

# %% [markdown]
# ### Esse material foi produzido com base no material de Thais Rodrigues Neubauer
